# %%
from datetime import date, timedelta
from covid_registry import CovidRegistry
import pandas as pd

# %% [markdown]
# # Dados de abril

# %%
grande_rio = [
    'Rio de Janeiro',
    'São Gonçalo',
    'Duque de Caxias',
    'Nova Iguaçu',
    'Niteroi',
    'Belford Roxo',
    'São João de Meriti',
    'Mage',
    'Itaborai',
    'Mesquita',
    'Nilópolis',
    'Maricá',
    'Queimados',
    'Itaguai',
    'Japeri',
    'Seropedica',
    'Guapimirim',
    'Paracambi',
    'Tanguá',
]

# %%
name = 'abril/grande_rio_abril.csv'
pkl = 'abril/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200401', end='20200430')
    await reg.dump(dates, states=['RJ'], cities=grande_rio, file=name, pkl=pkl)
# Out:
# This operation will take 5700 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/5700 requests -- 87 failures -- Elapsed: 0:00:20.229140
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/5700 requests -- 66 failures -- Elapsed: 0:00:40.070518
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/5700 requests -- 72 failures -- Elapsed: 0:00:57.951570
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/5700 requests -- 61 failures -- Elapsed: 0:01:16.197584
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/5700 requests -- 58 failures -- Elapsed: 0:01:33.287011
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/5700 requests -- 48 failures -- Elapsed: 0:01:58.936163
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0007 -- 1400/5700 requests -- 48 failures -- Elapsed: 0:02:16.659205
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0008 -- 1600/5700 requests -- 63 failures -- Elapsed: 0:02:40.751965
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0009 -- 1800/5700 requests -- 75 failures -- Elapsed: 0:02:59.803337
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0010 -- 2000/5700 requests -- 85 failures -- Elapsed: 0:03:17.093639
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0011 -- 2200/5700 requests -- 92 failures -- Elapsed: 0:03:30.935835
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0012 -- 2400/5700 requests -- 73 failures -- Elapsed: 0:03:42.728578
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0013 -- 2600/5700 requests -- 101 failures -- Elapsed: 0:04:00.983225
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0014 -- 2800/5700 requests -- 98 failures -- Elapsed: 0:04:18.569028
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0015 -- 3000/5700 requests -- 107 failures -- Elapsed: 0:04:34.693627
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0016 -- 3200/5700 requests -- 104 failures -- Elapsed: 0:04:51.877101
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0017 -- 3400/5700 requests -- 127 failures -- Elapsed: 0:05:07.099905
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0018 -- 3600/5700 requests -- 104 failures -- Elapsed: 0:05:23.551482
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0019 -- 3800/5700 requests -- 108 failures -- Elapsed: 0:05:55.769115
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0020 -- 4000/5700 requests -- 140 failures -- Elapsed: 0:06:16.166284
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0021 -- 4200/5700 requests -- 92 failures -- Elapsed: 0:06:30.334913
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0022 -- 4400/5700 requests -- 69 failures -- Elapsed: 0:06:44.727846
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0023 -- 4600/5700 requests -- 53 failures -- Elapsed: 0:06:57.778941
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0024 -- 4800/5700 requests -- 0 failures -- Elapsed: 0:07:15.730893
# #0025 -- 5000/5700 requests -- 0 failures -- Elapsed: 0:07:29.016074
# #0026 -- 5200/5700 requests -- 42 failures -- Elapsed: 0:07:55.763020
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0027 -- 5400/5700 requests -- 64 failures -- Elapsed: 0:08:17.916748
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0028 -- 5600/5700 requests -- 69 failures -- Elapsed: 0:08:44.365173
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0029 -- 5700/5700 requests -- 15 failures -- Elapsed: 0:08:55.101479
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 2121 failures occured. Retrying...
# This operation will take 2121 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/2121 requests -- 82 failures -- Elapsed: 0:09:06.667026
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/2121 requests -- 116 failures -- Elapsed: 0:09:23.930151
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/2121 requests -- 125 failures -- Elapsed: 0:09:40.769684
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/2121 requests -- 102 failures -- Elapsed: 0:09:50.999987
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/2121 requests -- 92 failures -- Elapsed: 0:10:05.860545
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/2121 requests -- 92 failures -- Elapsed: 0:10:17.100276
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0007 -- 1400/2121 requests -- 83 failures -- Elapsed: 0:10:35.852437
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0008 -- 1600/2121 requests -- 69 failures -- Elapsed: 0:10:48.007506
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0009 -- 1800/2121 requests -- 73 failures -- Elapsed: 0:11:08.556162
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0010 -- 2000/2121 requests -- 121 failures -- Elapsed: 0:11:31.449471
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0011 -- 2121/2121 requests -- 58 failures -- Elapsed: 0:11:39.349156
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 1013 failures occured. Retrying...
# This operation will take 1013 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1013 requests -- 85 failures -- Elapsed: 0:11:50.090251
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1013 requests -- 87 failures -- Elapsed: 0:12:03.780825
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1013 requests -- 107 failures -- Elapsed: 0:12:20.945534
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1013 requests -- 84 failures -- Elapsed: 0:12:36.013415
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1013 requests -- 84 failures -- Elapsed: 0:12:48.129524
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1013/1013 requests -- 0 failures -- Elapsed: 0:12:49.618842
# 447 failures occured. Retrying...
# This operation will take 447 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/447 requests -- 108 failures -- Elapsed: 0:13:06.942202
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/447 requests -- 112 failures -- Elapsed: 0:13:21.148150
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 447/447 requests -- 12 failures -- Elapsed: 0:13:25.119610
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 232 failures occured. Retrying...
# This operation will take 232 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/232 requests -- 95 failures -- Elapsed: 0:13:35.368278
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 232/232 requests -- 1 failures -- Elapsed: 0:13:38.913150
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 96 failures occured. Retrying...
# This operation will take 96 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 96/96 requests -- 43 failures -- Elapsed: 0:13:45.272276
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 43 failures occured. Retrying...
# This operation will take 43 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 43/43 requests -- 11 failures -- Elapsed: 0:13:48.691466
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 11 failures occured. Retrying...
# This operation will take 11 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 11/11 requests -- 0 failures -- Elapsed: 0:13:49.646381

# %% [markdown]
# Verificando se há duplicatas:

# %%
df = pd.read_csv(
    name,
    usecols=['Date', 'State', 'City', 'Age', 'Gender', 'Place of Death', 'Cause', '#'],
    parse_dates=[1]
)

# %%
df.duplicated(keep=False).value_counts()
# Out:
# False    11033
# dtype: int64
