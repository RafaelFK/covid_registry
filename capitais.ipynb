# %%
from datetime import date, timedelta
from covid_registry import CovidRegistry
import pandas as pd

# %% [markdown]
# # Dados das Capitais estaduais do Brasil

# %%
reg_test = CovidRegistry()
await reg_test.connect()
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7f459405fa90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7f4594274150>

# %%
'Maceió' in reg_test.cities[reg_test.cities['uf'] == 'AL']['name'].unique()
# Out:
# False

# %%
await reg_test.close()

# %% [markdown]
# ## Acre

# %% [markdown]
# A capital do Acre é Rio Branco

# %%
name = 'Capitais/Acre/acre_rio_branco.csv'
pkl = 'Capitais/Acre/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['AC'], cities=['Rio Branco'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 52 failures -- Elapsed: 0:00:37.492758
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 33 failures -- Elapsed: 0:00:49.599517
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 4 failures -- Elapsed: 0:03:09.697763
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 4 failures -- Elapsed: 0:03:48.170998
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 9 failures -- Elapsed: 0:04:00.229898
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 34 failures -- Elapsed: 0:06:20.691237
# Errors found in chunk:
# ...

# %% [markdown]
# ## Alagoas

# %% [markdown]
# A capital de Alagoas é Maceió

# %%
name = 'Capitais/Alagoas/alagoas_maceio.csv'
pkl = 'Capitais/Alagoas/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['AL'], cities=['Maceio'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 113 failures -- Elapsed: 0:01:12.146891
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 84 failures -- Elapsed: 0:01:52.403141
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 45 failures -- Elapsed: 0:04:14.909147
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 95 failures -- Elapsed: 0:06:37.512405
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 122 failures -- Elapsed: 0:07:00.521346
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 161 failures -- Elapsed: 0:07:11.014079
# Errors found in chunk:
# ...

# %% [markdown]
# ## Amapá

# %% [markdown]
# A capital do Amapá é Macapá

# %%
name = 'Capitais/Amapa/Amapa_macapa.csv'
pkl = 'Capitais/Amapa/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['AP'], cities=['Macapa'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 45 failures -- Elapsed: 0:02:18.944716
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 54 failures -- Elapsed: 0:03:04.419754
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 48 failures -- Elapsed: 0:03:26.816331
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 18 failures -- Elapsed: 0:05:48.341071
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 54 failures -- Elapsed: 0:06:11.179674
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 81 failures -- Elapsed: 0:06:28.172533
# Errors found in chunk:
# ...

# %% [markdown]
# ## Amazonas

# %% [markdown]
# A capital do Amazonas é Manaus

# %%
name = 'Capitais/Amazonas/amazonas_manaus.csv'
pkl = 'Capitais/Amazonas/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['AM'], cities=['Manaus'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 32 failures -- Elapsed: 0:00:15.386456
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 50 failures -- Elapsed: 0:00:59.131717
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7f4596091110>
# #0003 -- 600/1550 requests -- 41 failures -- Elapsed: 0:02:16.258753
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 55 failures -- Elapsed: 0:02:55.475368
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 101 failures -- Elapsed: 0:03:13.116342
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# ...

# %% [markdown]
# ## Bahia

# %% [markdown]
# A capital da Bahia é Salvador

# %%
name = 'Capitais/Bahia/bahia_salvador.csv'
pkl = 'Capitais/Bahia/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['BA'], cities=['Salvador'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 151 failures -- Elapsed: 0:00:17.507371
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 147 failures -- Elapsed: 0:00:39.496426
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 154 failures -- Elapsed: 0:01:05.557299
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 157 failures -- Elapsed: 0:01:28.769010
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 105 failures -- Elapsed: 0:02:50.351068
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 155 failures -- Elapsed: 0:03:13.425308
# Errors found in chunk:
# ...

# %% [markdown]
# ## Ceará

# %% [markdown]
# A capital do Ceará é Fortaleza

# %%
name = 'Capitais/Ceara/ceara_fortaleza.csv'
pkl = 'Capitais/Ceara/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['CE'], cities=['Fortaleza'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 109 failures -- Elapsed: 0:01:18.691105
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 132 failures -- Elapsed: 0:01:59.982371
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 111 failures -- Elapsed: 0:02:45.732087
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 106 failures -- Elapsed: 0:03:33.091966
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 154 failures -- Elapsed: 0:04:16.126867
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 158 failures -- Elapsed: 0:04:36.538279
# Errors found in chunk:
# ...

# %% [markdown]
# ## Distrito Federal

# %% [markdown]
# A capital do Distrito Federal é Brasília

# %%
name = 'Capitais/Distrito_Federal/distrito_federal_brasilia.csv'
pkl = 'Capitais/Distrito_Federal/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['DF'], cities=['Brasília'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 77 failures -- Elapsed: 0:02:19.054713
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 56 failures -- Elapsed: 0:04:45.766219
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 106 failures -- Elapsed: 0:05:04.191793
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 61 failures -- Elapsed: 0:06:19.712008
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 92 failures -- Elapsed: 0:06:36.048502
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 44 failures -- Elapsed: 0:07:53.425310
# Errors found in chunk:
# ...

# %% [markdown]
# ## Espírito Santo

# %% [markdown]
# A capital do Espírito Santo é Vitória

# %%
name = 'Capitais/Espirito_Santo/espirito_santo_vitoria.csv'
pkl = 'Capitais/Espirito_Santo/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['ES'], cities=['Vitória'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 94 failures -- Elapsed: 0:00:11.769658
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 44 failures -- Elapsed: 0:02:33.629086
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 95 failures -- Elapsed: 0:02:52.456523
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 42 failures -- Elapsed: 0:04:09.476077
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 100 failures -- Elapsed: 0:05:22.711476
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 126 failures -- Elapsed: 0:05:47.022235
# Errors found in chunk:
# ...

# %% [markdown]
# ## Goiás

# %% [markdown]
# A capital de Goiás é Goiânia

# %%
name = 'Capitais/Goias/goias_goiania.csv'
pkl = 'Capitais/Goias/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['GO'], cities=['Goiânia'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 176 failures -- Elapsed: 0:00:17.001269
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 153 failures -- Elapsed: 0:00:30.942435
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 169 failures -- Elapsed: 0:00:49.852820
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 164 failures -- Elapsed: 0:01:03.825096
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 162 failures -- Elapsed: 0:01:17.676192
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 151 failures -- Elapsed: 0:01:31.057843
# Errors found in chunk:
# ...

# %% [markdown]
# ## Maranhão

# %% [markdown]
# A capital do Maranhão é São Luís

# %%
name = 'Capitais/Maranhao/maranhao_sao_luis.csv'
pkl = 'Capitais/Maranhao/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['MA'], cities=['São Luís'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 118 failures -- Elapsed: 0:00:11.831928
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 116 failures -- Elapsed: 0:00:22.179971
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 127 failures -- Elapsed: 0:00:34.133006
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 115 failures -- Elapsed: 0:00:45.665003
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 136 failures -- Elapsed: 0:00:57.709216
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 144 failures -- Elapsed: 0:01:08.809428
# Errors found in chunk:
# ...

# %% [markdown]
# ## Mato Grosso

# %% [markdown]
# A capital do Mato Grosso é Cuiabá

# %%
name = 'Capitais/Mato_Grosso/mato_grosso_cuiaba.csv'
pkl = 'Capitais/Mato_Grosso/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['MT'], cities=['Cuiaba'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 126 failures -- Elapsed: 0:00:10.996347
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 118 failures -- Elapsed: 0:00:23.308456
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 133 failures -- Elapsed: 0:00:34.613037
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 120 failures -- Elapsed: 0:00:46.243682
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 109 failures -- Elapsed: 0:00:58.636279
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 136 failures -- Elapsed: 0:01:09.347647
# Errors found in chunk:
# ...

# %% [markdown]
# ## Mato Grosso do Sul

# %% [markdown]
# A capital do Mato Grosso do Sul é Campo Grande

# %%
name = 'Capitais/Mato_Grosso_Sul/mato_grosso_sul_campo_grande.csv'
pkl = 'Capitais/Mato_Grosso_Sul/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['MS'], cities=['Campo Grande'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 126 failures -- Elapsed: 0:00:11.916248
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 139 failures -- Elapsed: 0:00:27.637946
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 155 failures -- Elapsed: 0:00:39.298076
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 154 failures -- Elapsed: 0:00:51.210801
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 144 failures -- Elapsed: 0:01:03.271989
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 151 failures -- Elapsed: 0:01:14.114546
# Errors found in chunk:
# ...

# %% [markdown]
# ## Minas Gerais

# %% [markdown]
# A capital de Minas Gerais é Belo Horizonte

# %%
name = 'Capitais/Minas_Gerais/minas_gerais_belo_horizonte.csv'
pkl = 'Capitais/Minas_Gerais/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['MG'], cities=['Belo Horizonte'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 159 failures -- Elapsed: 0:00:16.258413
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 152 failures -- Elapsed: 0:00:31.227708
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 167 failures -- Elapsed: 0:00:47.612384
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 151 failures -- Elapsed: 0:01:03.484866
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 159 failures -- Elapsed: 0:01:18.559670
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 168 failures -- Elapsed: 0:01:34.503145
# Errors found in chunk:
# ...

# %% [markdown]
# ## Pará

# %% [markdown]
# A capital do Pará é Belém

# %%
name = 'Capitais/Para/para_belem.csv'
pkl = 'Capitais/Para/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['PA'], cities=['Belém'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 147 failures -- Elapsed: 0:00:13.089344
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 145 failures -- Elapsed: 0:00:26.371343
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 144 failures -- Elapsed: 0:00:39.245983
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 149 failures -- Elapsed: 0:00:50.081101
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 151 failures -- Elapsed: 0:01:05.071410
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 168 failures -- Elapsed: 0:01:20.722275
# Errors found in chunk:
# ...

# %% [markdown]
# ## Paraíba

# %% [markdown]
# A capital da Paraíba é João Pessoa

# %%
name = 'Capitais/Paraiba/paraiba_joao_pessoa.csv'
pkl = 'Capitais/Paraiba/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['PB'], cities=['Joao Pessoa'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 143 failures -- Elapsed: 0:00:10.879791
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 129 failures -- Elapsed: 0:00:23.039533
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 127 failures -- Elapsed: 0:00:35.003790
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 126 failures -- Elapsed: 0:00:47.125689
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 162 failures -- Elapsed: 0:00:58.558245
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 159 failures -- Elapsed: 0:01:12.526525
# Errors found in chunk:
# ...

# %% [markdown]
# ## Paraná

# %% [markdown]
# A capital do Paraná é Curitiba

# %%
name = 'Capitais/Parana/parana_curitiba.csv'
pkl = 'Capitais/Parana/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['PR'], cities=['Curitiba'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 184 failures -- Elapsed: 0:00:14.423194
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 157 failures -- Elapsed: 0:00:30.123564
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 152 failures -- Elapsed: 0:00:49.016217
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 191 failures -- Elapsed: 0:01:05.323006
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 166 failures -- Elapsed: 0:01:18.784285
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 166 failures -- Elapsed: 0:01:32.905539
# Errors found in chunk:
# ...

# %% [markdown]
# ## Pernambuco

# %% [markdown]
# A capital de Pernambuco é Recife

# %%
name = 'Capitais/Pernambuco/pernambuco_recife.csv'
pkl = 'Capitais/Pernambuco/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['PE'], cities=['Recife'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 181 failures -- Elapsed: 0:00:25.865938
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 161 failures -- Elapsed: 0:00:46.461898
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 151 failures -- Elapsed: 0:01:04.846267
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 160 failures -- Elapsed: 0:01:22.990196
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 172 failures -- Elapsed: 0:01:40.578435
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 165 failures -- Elapsed: 0:01:57.381462
# Errors found in chunk:
# ...

# %% [markdown]
# ## Piauí

# %% [markdown]
# A capital do Piauí é Teresina

# %%
name = 'Capitais/Piaui/piaui_teresina.csv'
pkl = 'Capitais/Piaui/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['PI'], cities=['Teresina'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 103 failures -- Elapsed: 0:00:10.938543
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 114 failures -- Elapsed: 0:00:22.460040
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 99 failures -- Elapsed: 0:00:33.010060
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 113 failures -- Elapsed: 0:00:44.105121
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 110 failures -- Elapsed: 0:00:57.080718
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 101 failures -- Elapsed: 0:01:08.769896
# Errors found in chunk:
# ...

# %% [markdown]
# ## Rio Grande do Norte

# %% [markdown]
# A capital do Rio Grande do Norte é Natal

# %%
name = 'Capitais/Rio_Grande_Norte/rio_grande_norte_natal.csv'
pkl = 'Capitais/Rio_Grande_Norte/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['RN'], cities=['Natal'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 129 failures -- Elapsed: 0:00:10.115214
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 141 failures -- Elapsed: 0:00:22.572132
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 148 failures -- Elapsed: 0:00:33.251860
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 133 failures -- Elapsed: 0:00:44.696188
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 147 failures -- Elapsed: 0:00:55.951493
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 129 failures -- Elapsed: 0:01:07.174534
# Errors found in chunk:
# ...

# %% [markdown]
# ## Rio Grande do Sul

# %% [markdown]
# A capital do Rio Grande do Sul é Porto Alegre

# %%
name = 'Capitais/Rio_Grande_Sul/rio_grande_sul_porto_alegre.csv'
pkl = 'Capitais/Rio_Grande_Sul/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['RS'], cities=['Porto Alegre'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 148 failures -- Elapsed: 0:00:22.378659
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 159 failures -- Elapsed: 0:00:41.784705
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 160 failures -- Elapsed: 0:01:03.511297
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 154 failures -- Elapsed: 0:01:23.814581
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 177 failures -- Elapsed: 0:01:40.797261
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 177 failures -- Elapsed: 0:01:58.843163
# Errors found in chunk:
# ...

# %% [markdown]
# ## Rio de Janeiro

# %% [markdown]
# A capital do Rio de Janeiro é o Rio de Janeiro :)

# %%
name = 'Capitais/Rio_Janeiro/rio_janeiro_rio_janeiro.csv'
pkl = 'Capitais/Rio_Janeiro/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['RJ'], cities=['Rio de Janeiro'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 187 failures -- Elapsed: 0:00:37.585883
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 168 failures -- Elapsed: 0:01:16.648411
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 172 failures -- Elapsed: 0:02:07.339535
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 170 failures -- Elapsed: 0:02:57.641795
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 173 failures -- Elapsed: 0:03:40.072508
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 168 failures -- Elapsed: 0:04:18.604422
# Errors found in chunk:
# ...

# %% [markdown]
# ## Rondônia

# %% [markdown]
# A capital de Rondônia é Porto Velho

# %%
name = 'Capitais/Rondonia/rondonia_porto_velho.csv'
pkl = 'Capitais/Rondonia/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['RO'], cities=['Porto Velho'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 77 failures -- Elapsed: 0:00:11.296998
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 73 failures -- Elapsed: 0:00:23.481425
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 77 failures -- Elapsed: 0:00:35.058719
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 95 failures -- Elapsed: 0:00:44.581379
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 98 failures -- Elapsed: 0:00:54.321943
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 87 failures -- Elapsed: 0:01:04.614182
# Errors found in chunk:
# ...

# %% [markdown]
# ## Roraima

# %% [markdown]
# A capital de Roraima é Boa Vista

# %%
name = 'Capitais/Roraima/roraima_boa_vista.csv'
pkl = 'Capitais/Roraima/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['RR'], cities=['Boa Vista'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 90 failures -- Elapsed: 0:00:09.587415
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 145 failures -- Elapsed: 0:00:19.689512
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 144 failures -- Elapsed: 0:00:30.860897
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 151 failures -- Elapsed: 0:00:41.928066
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 136 failures -- Elapsed: 0:00:52.195868
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 166 failures -- Elapsed: 0:01:03.556791
# Errors found in chunk:
# ...

# %% [markdown]
# ## Santa Catarina

# %% [markdown]
# A capital de Santa Catarina é Florianópolis

# %%
name = 'Capitais/Santa_Catarina/santa_catarina_florianopolis.csv'
pkl = 'Capitais/Santa_Catarina/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['SC'], cities=['Florianopolis'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 67 failures -- Elapsed: 0:00:11.076840
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 125 failures -- Elapsed: 0:00:21.266039
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 102 failures -- Elapsed: 0:00:31.690593
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 102 failures -- Elapsed: 0:00:41.509012
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 104 failures -- Elapsed: 0:00:51.684499
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 137 failures -- Elapsed: 0:01:01.464854
# Errors found in chunk:
# ...

# %% [markdown]
# ## São Paulo

# %% [markdown]
# A capital de São Paulo é São Paulo

# %%
name = 'Capitais/Sao_Paulo/sao_paulo_sao_paulo.csv'
pkl = 'Capitais/Sao_Paulo/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['SP'], cities=['São Paulo'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 177 failures -- Elapsed: 0:01:03.932636
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 182 failures -- Elapsed: 0:02:07.936250
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 175 failures -- Elapsed: 0:03:10.036125
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 153 failures -- Elapsed: 0:04:12.965251
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 198 failures -- Elapsed: 0:04:56.031420
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 174 failures -- Elapsed: 0:05:59.964240
# Errors found in chunk:
# ...

# %% [markdown]
# ## Sergipe

# %% [markdown]
# A capital de Sergipe é Aracaju

# %%
name = 'Capitais/Sergipe/sergipe_aracaju.csv'
pkl = 'Capitais/Sergipe/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['SE'], cities=['Aracaju'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 137 failures -- Elapsed: 0:00:11.578998
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 133 failures -- Elapsed: 0:00:22.870464
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 130 failures -- Elapsed: 0:00:35.096743
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 137 failures -- Elapsed: 0:00:46.438346
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 137 failures -- Elapsed: 0:00:56.488550
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 139 failures -- Elapsed: 0:01:07.805492
# Errors found in chunk:
# ...

# %% [markdown]
# ## Tocantins

# %% [markdown]
# A capital do Tocantis é Palmas

# %%
name = 'Capitais/Tocantins/tocantins_palmas.csv'
pkl = 'Capitais/Tocantins/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200603')
    await reg.dump(dates, states=['TO'], cities=['Palmas'], file=name, pkl=pkl)
# Out:
# This operation will take 1550 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1550 requests -- 37 failures -- Elapsed: 0:00:09.680548
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1550 requests -- 43 failures -- Elapsed: 0:00:19.315297
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1550 requests -- 52 failures -- Elapsed: 0:00:29.816243
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1550 requests -- 81 failures -- Elapsed: 0:00:39.370749
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1550 requests -- 80 failures -- Elapsed: 0:00:49.228028
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1550 requests -- 67 failures -- Elapsed: 0:00:59.759008
# Errors found in chunk:
# ...

# %% [markdown]
# # Juntando tudo

# %%
from pathlib import Path

p = Path('Capitais')

# Obtendo lista de tabelas
csvs = list(p.glob('**/*.csv'))

# Carregando tabelas como dataframes
dfs = [
    pd.read_csv(
        csv,
        usecols=['Date', 'State', 'City', 'Age', 'Gender', 'Place of Death', 'Cause', '#'],
        parse_dates=[1]
    )
    for csv in csvs
]

# Concatenando dfs
capitais_df = pd.concat(dfs)

# Ordenando df
capitais_df.sort_values(by=['Date', 'State', 'City', 'Age', 'Gender', 'Place of Death', 'Cause'], axis=0, inplace=True)

# Salvando
capitais_df.to_csv('Capitais/obitos_covid_capitais.csv', index=False)
