# %%
from datetime import date, timedelta
from covid_registry import CovidRegistry
import pandas as pd

# %% [markdown]
# # Óbitos relacionados à Covid no Brasil

# %% [markdown]
# Mês de janeiro:

# %%
name = 'nacional/janeiro/obitos_covid_janeiro.csv'
pkl = 'nacional/janeiro/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200101', end='20200131')
    await reg.dump(dates, file=name, pkl=pkl)
# Out:
# This operation will take 1739100 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1739100 requests -- 0 failures -- Elapsed: 0:00:08.956927
# #0002 -- 400/1739100 requests -- 0 failures -- Elapsed: 0:00:18.895082
# #0003 -- 600/1739100 requests -- 0 failures -- Elapsed: 0:00:28.914913
# #0004 -- 800/1739100 requests -- 0 failures -- Elapsed: 0:00:39.033980
# #0005 -- 1000/1739100 requests -- 0 failures -- Elapsed: 0:00:55.001100
# #0006 -- 1200/1739100 requests -- 0 failures -- Elapsed: 0:01:04.956871
# #0007 -- 1400/1739100 requests -- 0 failures -- Elapsed: 0:01:15.388572
# #0008 -- 1600/1739100 requests -- 0 failures -- Elapsed: 0:01:25.789309
# #0009 -- 1800/1739100 requests -- 0 failures -- Elapsed: 0:01:36.199821
# #0010 -- 2000/1739100 requests -- 0 failures -- Elapsed: 0:01:46.645930
# #0011 -- 2200/1739100 requests -- 0 failures -- Elapsed: 0:02:02.362363
# #0012 -- 2400/1739100 requests -- 0 failures -- Elapsed: 0:02:13.126889
# ...

# %% [markdown]
# Mês de fevereiro:

# %%
name = 'nacional/fevereiro/obitos_covid_fevereiro.csv'
pkl = 'nacional/fevereiro/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200201', end='20200229')
    await reg.dump(dates, file=name, pkl=pkl)

# %% [markdown]
# Mês de março:

# %%
name = 'nacional/marco/obitos_covid_marco.csv'
pkl = 'nacional/marco/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200301', end='20200331')
    await reg.dump(dates, file=name, pkl=pkl)

# %% [markdown]
# Mês de abril:

# %%
name = 'nacional/abril/obitos_covid_abril.csv'
pkl = 'nacional/abril/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200401', end='20200430')
    await reg.dump(dates, file=name, pkl=pkl)

# %% [markdown]
# Mês de maio:

# %%
name = 'nacional/maio/obitos_covid_maio.csv'
pkl = 'nacional/maio/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200501', end='20200531')
    await reg.dump(dates, file=name, pkl=pkl)
