# %%
from datetime import date, timedelta
from covid_registry import CovidRegistry
import pandas as pd

# %% [markdown]
# # Dados de Maio

# %%
grande_rio = [
    'Rio de Janeiro',
    'São Gonçalo',
    'Duque de Caxias',
    'Nova Iguaçu',
    'Niteroi',
    'Belford Roxo',
    'São João de Meriti',
    'Mage',
    'Itaborai',
    'Mesquita',
    'Nilópolis',
    'Maricá',
    'Queimados',
    'Itaguai',
    'Japeri',
    'Seropedica',
    'Guapimirim',
    'Paracambi',
    'Tanguá',
]

# %%
name = 'maio/grande_rio_maio.csv'
pkl = 'maio/remaining_tasks.pkl'

async with CovidRegistry() as reg:
    dates = pd.date_range(start='20200501', end='20200531')
    await reg.dump(dates, states=['RJ'], cities=grande_rio, file=name, pkl=pkl)
# Out:
# This operation will take 5890 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/5890 requests -- 94 failures -- Elapsed: 0:00:24.128430
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/5890 requests -- 79 failures -- Elapsed: 0:00:43.356193
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/5890 requests -- 99 failures -- Elapsed: 0:01:01.714689
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/5890 requests -- 81 failures -- Elapsed: 0:01:20.269021
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/5890 requests -- 76 failures -- Elapsed: 0:01:44.015481
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/5890 requests -- 74 failures -- Elapsed: 0:02:03.007099
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0007 -- 1400/5890 requests -- 62 failures -- Elapsed: 0:02:15.395736
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0008 -- 1600/5890 requests -- 70 failures -- Elapsed: 0:02:40.010679
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0009 -- 1800/5890 requests -- 79 failures -- Elapsed: 0:02:59.765510
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0010 -- 2000/5890 requests -- 86 failures -- Elapsed: 0:03:20.863660
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0011 -- 2200/5890 requests -- 89 failures -- Elapsed: 0:03:42.092589
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0012 -- 2400/5890 requests -- 84 failures -- Elapsed: 0:03:59.357606
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0013 -- 2600/5890 requests -- 105 failures -- Elapsed: 0:04:19.735125
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0014 -- 2800/5890 requests -- 94 failures -- Elapsed: 0:04:35.423033
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0015 -- 3000/5890 requests -- 94 failures -- Elapsed: 0:04:51.619329
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0016 -- 3200/5890 requests -- 130 failures -- Elapsed: 0:05:10.271535
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0017 -- 3400/5890 requests -- 137 failures -- Elapsed: 0:05:32.076909
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0018 -- 3600/5890 requests -- 133 failures -- Elapsed: 0:05:55.600339
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0019 -- 3800/5890 requests -- 103 failures -- Elapsed: 0:06:17.467180
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0020 -- 4000/5890 requests -- 121 failures -- Elapsed: 0:06:40.695415
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0021 -- 4200/5890 requests -- 84 failures -- Elapsed: 0:06:58.255788
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0022 -- 4400/5890 requests -- 142 failures -- Elapsed: 0:07:21.543140
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0023 -- 4600/5890 requests -- 101 failures -- Elapsed: 0:07:36.605123
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0024 -- 4800/5890 requests -- 78 failures -- Elapsed: 0:07:55.506906
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0025 -- 5000/5890 requests -- 45 failures -- Elapsed: 0:08:11.350505
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0026 -- 5200/5890 requests -- 62 failures -- Elapsed: 0:08:27.073389
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0027 -- 5400/5890 requests -- 95 failures -- Elapsed: 0:08:50.977931
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0028 -- 5600/5890 requests -- 79 failures -- Elapsed: 0:09:04.698575
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0029 -- 5800/5890 requests -- 68 failures -- Elapsed: 0:09:18.277795
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0030 -- 5890/5890 requests -- 13 failures -- Elapsed: 0:09:22.651801
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 2657 failures occured. Retrying...
# This operation will take 2657 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/2657 requests -- 95 failures -- Elapsed: 0:09:32.639216
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/2657 requests -- 92 failures -- Elapsed: 0:09:53.713334
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/2657 requests -- 101 failures -- Elapsed: 0:10:09.637059
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/2657 requests -- 102 failures -- Elapsed: 0:10:22.727758
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/2657 requests -- 102 failures -- Elapsed: 0:10:46.474439
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/2657 requests -- 125 failures -- Elapsed: 0:11:07.654534
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0007 -- 1400/2657 requests -- 86 failures -- Elapsed: 0:11:20.014042
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0008 -- 1600/2657 requests -- 115 failures -- Elapsed: 0:11:33.287065
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0009 -- 1800/2657 requests -- 78 failures -- Elapsed: 0:11:46.304917
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0010 -- 2000/2657 requests -- 90 failures -- Elapsed: 0:11:59.027449
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0011 -- 2200/2657 requests -- 64 failures -- Elapsed: 0:12:10.807787
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0012 -- 2400/2657 requests -- 84 failures -- Elapsed: 0:12:21.176731
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0013 -- 2600/2657 requests -- 100 failures -- Elapsed: 0:12:33.569941
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0014 -- 2657/2657 requests -- 30 failures -- Elapsed: 0:12:37.746673
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 1264 failures occured. Retrying...
# This operation will take 1264 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/1264 requests -- 130 failures -- Elapsed: 0:12:48.950574
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/1264 requests -- 108 failures -- Elapsed: 0:13:03.506128
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 600/1264 requests -- 92 failures -- Elapsed: 0:13:23.836739
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0004 -- 800/1264 requests -- 69 failures -- Elapsed: 0:13:39.376759
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0005 -- 1000/1264 requests -- 70 failures -- Elapsed: 0:13:49.068507
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0006 -- 1200/1264 requests -- 92 failures -- Elapsed: 0:14:03.459819
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0007 -- 1264/1264 requests -- 22 failures -- Elapsed: 0:14:07.870519
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 583 failures occured. Retrying...
# This operation will take 583 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/583 requests -- 105 failures -- Elapsed: 0:14:31.358656
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 400/583 requests -- 125 failures -- Elapsed: 0:14:45.229663
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0003 -- 583/583 requests -- 101 failures -- Elapsed: 0:14:58.685957
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 331 failures occured. Retrying...
# This operation will take 331 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 200/331 requests -- 87 failures -- Elapsed: 0:15:09.556680
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# #0002 -- 331/331 requests -- 57 failures -- Elapsed: 0:15:20.500879
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 144 failures occured. Retrying...
# This operation will take 144 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 144/144 requests -- 69 failures -- Elapsed: 0:15:38.026029
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 69 failures occured. Retrying...
# This operation will take 69 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 69/69 requests -- 33 failures -- Elapsed: 0:15:43.402076
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 33 failures occured. Retrying...
# This operation will take 33 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 33/33 requests -- 9 failures -- Elapsed: 0:15:55.191204
# Errors found in chunk:
# ["<class 'aiohttp.client_exceptions.ClientResponseError'>"]
# 9 failures occured. Retrying...
# This operation will take 9 requests. Checkpoints will be created once every 200 requests.
# #0001 -- 9/9 requests -- 0 failures -- Elapsed: 0:16:02.963034

# %% [markdown]
# Verificando se há duplicatas:

# %%
df = pd.read_csv(
    name,
    usecols=['Date', 'State', 'City', 'Age', 'Gender', 'Place of Death', 'Cause', '#'],
    parse_dates=[1]
)

# %%
df.duplicated(keep=False).value_counts()
# Out:
# False    12199
# dtype: int64
